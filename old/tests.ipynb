# %%
# %load_ext autoreload
# %autoreload 2

# %%
import torch
from env import Box

import matplotlib.pyplot as plt
import numpy as np

from TruncatedNormal import TruncatedNormal

# %%
env = Box(dim=2, device_str="cpu")

# %%
# Create a meshgrid of states in [0, 1]^2 in torch
n = 100
x = torch.linspace(0, 1, n)
y = torch.linspace(0, 1, n)
xx, yy = torch.meshgrid(x, y)
states = torch.stack([xx, yy], dim=-1).reshape(-1, 2)
states.shape
# Out:
# torch.Size([10000, 2])

# %%
rewards  = env.reward(states)
plt.imshow(rewards.reshape(n, n))
plt.colorbar()
plt.show()

# %%
env.reward(torch.zeros(2)).log()
# Out:
# tensor(-0.5108)

# %%
N_TRAJ = 10

# %%
actions_sampler = RandomActionsSampler(env, terminal_action_prob=0.1)
trajectories_sampler = TrajectoriesSampler(env, actions_sampler)

# %%
trajectories, actionss, logprobs = trajectories_sampler.sample(N_TRAJ)

# %%
states = get_last_states(env, trajectories)
# scatter plot of the last states
plt.scatter(states[:, 0], states[:, 1])

# %%
# make a figure of size 6, 6
plt.figure(figsize=(6, 6))
# list of 10 different colors
colors = plt.cm.rainbow(np.linspace(0, 1, N_TRAJ))
for i in range(10):
    plt.plot(trajectories[i, :, 0], trajectories[i, :, 1], color=colors[i])

# %%
model = BoxModel(logvar=False)
actions_sampler = NNActionsSampler(env, model, std=0.1)

# %%
trajectories_sampler = TrajectoriesSampler(env, actions_sampler)

# %%
trajectories, actionss, logprobs = trajectories_sampler.sample(10)

# %%
logprobs
# Out:
# tensor([-0.7129, -0.0591,  1.2486, -0.7129, -0.7129, -0.7129,  0.7952, -0.7129,
#         -0.7129, -0.7129], grad_fn=<AddBackward0>)

# %%
# list of 10 different colors
colors = plt.cm.rainbow(np.linspace(0, 1, N_TRAJ))
for i in range(10):
    plt.plot(trajectories[i, :, 0], trajectories[i, :, 1], color=colors[i])

# %%
bw_model = BoxModel(logvar=False)

# %%
lr = 1e-3
lr_Z = 5e-2
BS = 256
logZ = torch.zeros(1, requires_grad=True)
optimizer = torch.optim.Adam(model.parameters(), lr=lr)
optimizer.add_param_group({"params": bw_model.parameters(), "lr": lr})
optimizer.add_param_group({"params": [logZ], "lr": lr_Z})

for i in range(int(1e5)):
    optimizer.zero_grad()
    trajectories, actionss, logprobs = trajectories_sampler.sample(BS)
    last_states = get_last_states(env, trajectories)
    logrewards = env.reward(last_states).log()
    bw_logprobs = evaluate_backward_logprobs(env, bw_model, trajectories, actionss, bw_std=0.1)
    loss = torch.mean((logZ + logprobs - bw_logprobs - logrewards) ** 2)
    loss.backward()
    optimizer.step()
    if i % 100 == 0:
        print(loss.item())
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In [12], line 16
#      14 bw_logprobs = evaluate_backward_logprobs(env, bw_model, trajectories, actionss, bw_std=0.1)
#      15 loss = torch.mean((logZ + logprobs - bw_logprobs - logrewards) ** 2)
# ---> 16 loss.backward()
#      17 optimizer.step()
#      18 if i % 100 == 0:
#
# File ~/opt/miniconda3/envs/contgfn/lib/python3.10/site-packages/torch/_tensor.py:487, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     477 if has_torch_function_unary(self):
#     478     return handle_torch_function(
#     479         Tensor.backward,
#     480         (self,),
#    (...)
#     485         inputs=inputs,
#     486     )
# --> 487 torch.autograd.backward(
#     488     self, gradient, retain_graph, create_graph, inputs=inputs
#     489 )
#
# File ~/opt/miniconda3/envs/contgfn/lib/python3.10/site-packages/torch/autograd/__init__.py:197, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     192     retain_graph = create_graph
#     194 # The reason we repeat same the comment below is that
#     195 # some Python versions print out the first line of a multi-line function
#     196 # calls in the traceback and some print out the last line
# --> 197 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     198     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     199     allow_unreachable=True, accumulate_grad=True)
#
# RuntimeError: one of the variables needed for gradient computation has been modified by an inplace operation: [torch.FloatTensor [298]], which is output 0 of SigmoidBackward0, is at version 1; expected version 0 instead. Hint: enable anomaly detection to find the operation that failed to compute its gradient, with torch.autograd.set_detect_anomaly(True).

# %%
trajectories
# Out:
# tensor([[[0.0000, 0.0000],
#          [  -inf,   -inf],
#          [  -inf,   -inf],
#          [  -inf,   -inf]],
#
#         [[0.0000, 0.0000],
#          [0.0666, 0.0593],
#          [  -inf,   -inf],
#          [  -inf,   -inf]],
#
#         [[0.0000, 0.0000],
#          [0.0321, 0.0445],
#          [0.0788, 0.0969],
#          [  -inf,   -inf]],
#
#         [[0.0000, 0.0000],
#          [  -inf,   -inf],
#          [  -inf,   -inf],
#          [  -inf,   -inf]],
#
#         [[0.0000, 0.0000],
#          [  -inf,   -inf],
#          [  -inf,   -inf],
#          [  -inf,   -inf]],
#
#         [[0.0000, 0.0000],
#          [  -inf,   -inf],
#          [  -inf,   -inf],
#          [  -inf,   -inf]],
#
#         [[0.0000, 0.0000],
#          [0.0404, 0.0501],
#          [  -inf,   -inf],
#          [  -inf,   -inf]],
#
#         [[0.0000, 0.0000],
#          [  -inf,   -inf],
#          [  -inf,   -inf],
#          [  -inf,   -inf]],
#
#         [[0.0000, 0.0000],
#          [  -inf,   -inf],
#          [  -inf,   -inf],
#          [  -inf,   -inf]],
#
#         [[0.0000, 0.0000],
#          [  -inf,   -inf],
#          [  -inf,   -inf],
#          [  -inf,   -inf]]])

# %%
non_sink = ~torch.all(trajectories == env.sink_state, dim=-1)

trajectories[non_sink]
# Out:
# tensor([[0.0000, 0.0000],
#         [0.0000, 0.0000],
#         [0.0666, 0.0593],
#         [0.0000, 0.0000],
#         [0.0321, 0.0445],
#         [0.0788, 0.0969],
#         [0.0000, 0.0000],
#         [0.0000, 0.0000],
#         [0.0000, 0.0000],
#         [0.0000, 0.0000],
#         [0.0404, 0.0501],
#         [0.0000, 0.0000],
#         [0.0000, 0.0000],
#         [0.0000, 0.0000]])

# %%
non_sink
# Out:
# tensor([[ True, False, False, False],
#         [ True,  True, False, False],
#         [ True,  True,  True, False],
#         [ True, False, False, False],
#         [ True, False, False, False],
#         [ True, False, False, False],
#         [ True,  True, False, False],
#         [ True, False, False, False],
#         [ True, False, False, False],
#         [ True, False, False, False]])

# %%
non_sink.cumsum(dim=-1).argmax(dim=-1)
# Out:
# tensor([0, 1, 2, 0, 0, 0, 1, 0, 0, 0])

# %%
mask = torch.zeros_like(non_sink).bool()
mask.scatter_(1, non_sink.cumsum(dim=-1).argmax(dim=-1, keepdim=True), True)
# Out:
# tensor([[ True, False, False, False],
#         [False,  True, False, False],
#         [False, False,  True, False],
#         [ True, False, False, False],
#         [ True, False, False, False],
#         [ True, False, False, False],
#         [False,  True, False, False],
#         [ True, False, False, False],
#         [ True, False, False, False],
#         [ True, False, False, False]])

# %%
trajectories[mask]
# Out:
# tensor([[0.0000, 0.0000],
#         [0.0666, 0.0593],
#         [0.0788, 0.0969],
#         [0.0000, 0.0000],
#         [0.0000, 0.0000],
#         [0.0000, 0.0000],
#         [0.0404, 0.0501],
#         [0.0000, 0.0000],
#         [0.0000, 0.0000],
#         [0.0000, 0.0000]])

# %%
last_non_sink
# Out:
# tensor([[[0., 0.],
#          [-inf, -inf],
#          [-inf, -inf],
#          [0., 0.],
#          [0., 0.],
#          [0., 0.],
#          [-inf, -inf],
#          [0., 0.],
#          [0., 0.],
#          [0., 0.]]])

# %%
trajectories
# Out:
# tensor([[[0.0000, 0.0000],
#          [  -inf,   -inf],
#          [  -inf,   -inf],
#          [  -inf,   -inf]],
#
#         [[0.0000, 0.0000],
#          [0.0666, 0.0593],
#          [  -inf,   -inf],
#          [  -inf,   -inf]],
#
#         [[0.0000, 0.0000],
#          [0.0321, 0.0445],
#          [0.0788, 0.0969],
#          [  -inf,   -inf]],
#
#         [[0.0000, 0.0000],
#          [  -inf,   -inf],
#          [  -inf,   -inf],
#          [  -inf,   -inf]],
#
#         [[0.0000, 0.0000],
#          [  -inf,   -inf],
#          [  -inf,   -inf],
#          [  -inf,   -inf]],
#
#         [[0.0000, 0.0000],
#          [  -inf,   -inf],
#          [  -inf,   -inf],
#          [  -inf,   -inf]],
#
#         [[0.0000, 0.0000],
#          [0.0404, 0.0501],
#          [  -inf,   -inf],
#          [  -inf,   -inf]],
#
#         [[0.0000, 0.0000],
#          [  -inf,   -inf],
#          [  -inf,   -inf],
#          [  -inf,   -inf]],
#
#         [[0.0000, 0.0000],
#          [  -inf,   -inf],
#          [  -inf,   -inf],
#          [  -inf,   -inf]],
#
#         [[0.0000, 0.0000],
#          [  -inf,   -inf],
#          [  -inf,   -inf],
#          [  -inf,   -inf]]])

# %%
from torch.distributions import Beta, MixtureSameFamily, Categorical, Independent

# %%
beta = Beta(torch.tensor([10.0]), torch.tensor([5.0]))
plt.hist(beta.sample((100000,)).numpy(), bins=1000)
plt.show()

# %%
tru = TruncatedNormal(torch.tensor([[0.8], [0.2]]), torch.tensor([[0.1], [0.05]]),
 torch.tensor([[0.0], [0.0]]), torch.tensor([[1.0], [1.0]]))

tutu = Independent(tru, 1)

mixture_dist = MixtureSameFamily(Categorical(torch.tensor([0.5, 0.5])), tutu)



plt.plot(torch.linspace(0, 1, 1000).numpy(), mixture_dist.log_prob(torch.linspace(0, 1, 1000)).exp().numpy())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [36], line 10
#       4 tutu = Independent(tru, 1)
#       6 mixture_dist = MixtureSameFamily(Categorical(torch.tensor([0.5, 0.5])), tutu)
# ---> 10 plt.plot(torch.linspace(0, 1, 1000).numpy(), mixture_dist.log_prob(torch.linspace(0, 1, 1000)).exp().numpy())
#
# File ~/opt/miniconda3/envs/contgfn/lib/python3.10/site-packages/torch/distributions/mixture_same_family.py:150, in MixtureSameFamily.log_prob(self, x)
#     148 def log_prob(self, x):
#     149     if self._validate_args:
# --> 150         self._validate_sample(x)
#     151     x = self._pad(x)
#     152     log_prob_x = self.component_distribution.log_prob(x)  # [S, B, k]
#
# File ~/opt/miniconda3/envs/contgfn/lib/python3.10/site-packages/torch/distributions/distribution.py:275, in Distribution._validate_sample(self, value)
#     273 event_dim_start = len(value.size()) - len(self._event_shape)
#     274 if value.size()[event_dim_start:] != self._event_shape:
# --> 275     raise ValueError('The right-most size of value must match event_shape: {} vs {}.'.
#     276                      format(value.size(), self._event_shape))
#     278 actual_shape = value.size()
#     279 expected_shape = self._batch_shape + self._event_shape
#
# ValueError: The right-most size of value must match event_shape: torch.Size([1000]) vs torch.Size([1]).

# %%
tru.sample()
# Out:
# tensor([[0.8207],
#         [0.2235]])

# %%
mixture_dist.log_prob(mixture_dist.sample(torch.Size([3])))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In [67], line 1
# ----> 1 mixture_dist.log_prob(mixture_dist.sample(torch.Size([3])))
#
# File ~/opt/miniconda3/envs/contgfn/lib/python3.10/site-packages/torch/distributions/mixture_same_family.py:150, in MixtureSameFamily.log_prob(self, x)
#     148 def log_prob(self, x):
#     149     if self._validate_args:
# --> 150         self._validate_sample(x)
#     151     x = self._pad(x)
#     152     log_prob_x = self.component_distribution.log_prob(x)  # [S, B, k]
#
# File ~/opt/miniconda3/envs/contgfn/lib/python3.10/site-packages/torch/distributions/distribution.py:292, in Distribution._validate_sample(self, value)
#     290     return
#     291 assert support is not None
# --> 292 valid = support.check(value)
#     293 if not valid.all():
#     294     raise ValueError(
#     295         "Expected value argument "
#     296         f"({type(value).__name__} of shape {tuple(value.shape)}) "
#    (...)
#     299         f"but found invalid values:\n{value}"
#     300     )
#
# File ~/opt/miniconda3/envs/contgfn/lib/python3.10/site-packages/torch/distributions/constraints.py:209, in _IndependentConstraint.check(self, value)
#     208 def check(self, value):
# --> 209     result = self.base_constraint.check(value)
#     210     if result.dim() < self.reinterpreted_batch_ndims:
#     211         expected = self.base_constraint.event_dim + self.reinterpreted_batch_ndims
#
# File ~/opt/miniconda3/envs/contgfn/lib/python3.10/site-packages/torch/distributions/constraints.py:372, in _Interval.check(self, value)
#     371 def check(self, value):
# --> 372     return (self.lower_bound <= value) & (value <= self.upper_bound)
#
# RuntimeError: The size of tensor a (2) must match the size of tensor b (3) at non-singleton dimension 0

# %%
plt.hist(mixture_dist.sample((100000,)).numpy(), bins=1000)
plt.show()

# %%
mixture_dist.log_prob(torch.linspace(0, 1, 3).unsqueeze(-1))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In [61], line 1
# ----> 1 mixture_dist.log_prob(torch.linspace(0, 1, 3).unsqueeze(-1))
#
# File ~/opt/miniconda3/envs/contgfn/lib/python3.10/site-packages/torch/distributions/mixture_same_family.py:150, in MixtureSameFamily.log_prob(self, x)
#     148 def log_prob(self, x):
#     149     if self._validate_args:
# --> 150         self._validate_sample(x)
#     151     x = self._pad(x)
#     152     log_prob_x = self.component_distribution.log_prob(x)  # [S, B, k]
#
# File ~/opt/miniconda3/envs/contgfn/lib/python3.10/site-packages/torch/distributions/distribution.py:292, in Distribution._validate_sample(self, value)
#     290     return
#     291 assert support is not None
# --> 292 valid = support.check(value)
#     293 if not valid.all():
#     294     raise ValueError(
#     295         "Expected value argument "
#     296         f"({type(value).__name__} of shape {tuple(value.shape)}) "
#    (...)
#     299         f"but found invalid values:\n{value}"
#     300     )
#
# File ~/opt/miniconda3/envs/contgfn/lib/python3.10/site-packages/torch/distributions/constraints.py:209, in _IndependentConstraint.check(self, value)
#     208 def check(self, value):
# --> 209     result = self.base_constraint.check(value)
#     210     if result.dim() < self.reinterpreted_batch_ndims:
#     211         expected = self.base_constraint.event_dim + self.reinterpreted_batch_ndims
#
# File ~/opt/miniconda3/envs/contgfn/lib/python3.10/site-packages/torch/distributions/constraints.py:372, in _Interval.check(self, value)
#     371 def check(self, value):
# --> 372     return (self.lower_bound <= value) & (value <= self.upper_bound)
#
# RuntimeError: The size of tensor a (2) must match the size of tensor b (3) at non-singleton dimension 0

# %%
torch.linspace(0, 1, 2).unsqueeze(-1)
# Out:
# tensor([[0.],
#         [1.]])

# %%
alphas = torch.tensor([1.2, 1.3])
betas = torch.tensor([1.0, 1.0])

alphas_2 = torch.tensor([[1.2, 1.3], [1.2, 1.3]])
betas_2 = torch.tensor([[1.0, 1.0], [1.0, 1.0]])

beta = Beta(alphas, betas)
beta_2 = Independent(Beta(alphas_2, betas_2), 1)

# %%
xx = beta_2.sample()

# %%
beta_2.log_prob(xx)
# Out:
# tensor([-0.1928,  0.3833])

# %%
beta.log_prob(xx[1])
# Out:
# tensor([0.1270, 0.2563])

# %%
xx
# Out:
# tensor([[0.2572, 0.2953],
#         [0.7584, 0.9800]])
